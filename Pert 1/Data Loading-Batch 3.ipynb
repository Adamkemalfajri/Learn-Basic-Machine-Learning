# %% [markdown]
# # Data Loading

# %%
#import library
import sys
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %% [markdown]
# ### Check Version

# %%
print('python version :', sys.version)
print('pandas :', pd.__version__)
print('numpy :', np.__version__)
print('matplotlib :', matplotlib.__version__)
print('seaborn :', sns.__version__)
# Out:
# python version : 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]
# pandas : 1.0.1
# numpy : 1.18.1
# matplotlib : 3.1.3
# seaborn : 0.10.0

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('titanic.csv')

# %% [markdown]
# ### Read DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
print('jumlah row :', df.shape[0])
print('jumlah kolom :', df.shape[1])
# Out:
# jumlah row : 891
# jumlah kolom : 12

# %%
kolom_pilihan = ['Pclass','Name','Sex']

# %%
df[kolom_pilihan]
# Out:
#      Pclass                                               Name     Sex
# 0         3                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         3                             Heikkinen, Miss. Laina  female
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         3                           Allen, Mr. William Henry    male
# ..      ...                                                ...     ...
# 886       2                              Montvila, Rev. Juozas    male
# 887       1                       Graham, Miss. Margaret Edith  female
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1                              Behr, Mr. Karl Howell    male
# 890       3                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %%
df[['Pclass','Name','Sex']]
# Out:
#      Pclass                                               Name     Sex
# 0         3                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         3                             Heikkinen, Miss. Laina  female
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         3                           Allen, Mr. William Henry    male
# ..      ...                                                ...     ...
# 886       2                              Montvila, Rev. Juozas    male
# 887       1                       Graham, Miss. Margaret Edith  female
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1                              Behr, Mr. Karl Howell    male
# 890       3                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %%
df.loc[[10],['Name','Age']]
# Out:
#                                Name  Age
# 10  Sandstrom, Miss. Marguerite Rut  4.0

# %%
df.iloc[[10],[3,5]]
# Out:
#                                Name  Age
# 10  Sandstrom, Miss. Marguerite Rut  4.0

# %%
df.iloc[0:25,2:5]
# Out:
#     Pclass                                               Name     Sex
# 0        3                            Braund, Mr. Owen Harris    male
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2        3                             Heikkinen, Miss. Laina  female
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4        3                           Allen, Mr. William Henry    male
# 5        3                                   Moran, Mr. James    male
# 6        1                            McCarthy, Mr. Timothy J    male
# 7        3                     Palsson, Master. Gosta Leonard    male
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# ...

# %% [markdown]
# ## Describe Data

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## Check Value

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean_age = df['Age'].mean()
mean_age
# Out:
# 29.69911764705882

# %%
df['Age'] = df['Age'].fillna(mean_age)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df = df.drop('Cabin', axis = 1)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
df['Age'] = df['Age'].astype('int64')
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %% [markdown]
# ## Rename Columns

# %%
new_columns = {
 'PassengerId': 'PASS_ID',
 'Survived': 'SURVIVED', 
 'Pclass': 'PCLASS', 
 'Name': 'NAME', 
 'Sex': 'SEX', 
 'Age': 'AGE', 
 'SibSp': 'SIBSA', 
 'Parch': 'PARCA' , 
 'Fare': 'FARE',
 'Ticket' : 'TICKET',
 'Embarked' : "EMBARKED"
}

# %%
df = df.rename(columns = new_columns )
df.head()
# Out:
#    PASS_ID  SURVIVED  PCLASS  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
#
#                                                 NAME     SEX  AGE  SIBSA  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    PARCA            TICKET     FARE EMBARKED
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df = df.set_index('PASS_ID')
df.head()
# Out:
#          SURVIVED  PCLASS                                               NAME  \
# PASS_ID
# 1               0       3                            Braund, Mr. Owen Harris
# 2               1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3               1       3                             Heikkinen, Miss. Laina
# 4               1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5               0       3                           Allen, Mr. William Henry
#
#             SEX  AGE  SIBSA  PARCA            TICKET     FARE EMBARKED
# PASS_ID
# 1          male   22      1      0         A/5 21171   7.2500        S
# 2        female   38      1      0          PC 17599  71.2833        C
# 3        female   26      0      0  STON/O2. 3101282   7.9250        S
# 4        female   35      1      0            113803  53.1000        S
# 5          male   35      0      0            373450   8.0500        S

# %% [markdown]
# ## Grouping Data

# %%
df.groupby('PCLASS').sum()
# Out:
#         SURVIVED    AGE  SIBSA  PARCA        FARE
# PCLASS
# 1            136   7980     90     77  18177.4125
# 2             87   5484     74     70   3801.8417
# 3            119  12860    302    193   6714.6951

# %%
df.groupby('PCLASS')['SURVIVED'].sum()
# Out:
# PCLASS
# 1    136
# 2     87
# 3    119
# Name: SURVIVED, dtype: int64

# %%
df.groupby('PCLASS').mean()
# Out:
#         SURVIVED        AGE     SIBSA     PARCA       FARE
# PCLASS
# 1       0.629630  36.944444  0.416667  0.356481  84.154687
# 2       0.472826  29.804348  0.402174  0.380435  20.662183
# 3       0.242363  26.191446  0.615071  0.393075  13.675550

# %% [markdown]
# ## PIVOT

# %%
data = {
    'foo' : ['one']*3 + ['two']*3,
    'bar' : ['A', 'B', 'C', 'A', 'B', 'C'],
    'baz' : [1, 2, 3, 4, 5, 6],
    'zoo' : ['x', 'y', 'z', 'q', 'w', 't']
}
df_new = pd.DataFrame(data)
df_new
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
pivot_df = pd.pivot(df_new, index = "foo", columns="bar", values='baz')
pivot_df
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %% [markdown]
# ## CONCATE TABLE

# %%
df1 = df[['SURVIVED', 'PCLASS', 'NAME']]
df2 = df[['SEX', 'AGE', 'SIBSA']]
df3 = df[['PARCA', 'FARE']]

# %%
list_df = [df1,df2,df3]

# %%
df_concat = pd.concat(list_df, axis = 1)

# %%
df_concat
# Out:
#          SURVIVED  PCLASS                                               NAME  \
# PASS_ID
# 1               0       3                            Braund, Mr. Owen Harris
# 2               1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3               1       3                             Heikkinen, Miss. Laina
# 4               1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5               0       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 887             0       2                              Montvila, Rev. Juozas
# 888             1       1                       Graham, Miss. Margaret Edith
# 889             0       3           Johnston, Miss. Catherine Helen "Carrie"
# 890             1       1                              Behr, Mr. Karl Howell
# 891             0       3                                Dooley, Mr. Patrick
#
# ...

# %%
pd.concat([pd.DataFrame(i, index=[0]) 
           for i in 
           pd.read_json('https://financialmodelingprep.com/api/v3/company-key-metrics/AAPL?period=quarter')['metrics']], 
          ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-9c9c7505487e> in <module>
#       1 pd.concat([pd.DataFrame(i, index=[0])
#       2            for i in
# ----> 3            pd.read_json('https://financialmodelingprep.com/api/v3/company-key-metrics/AAPL?period=quarter')['metrics']],
#       4           ignore_index=True)
#
# E:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# E:\anaconda\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
# ...
